# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Load the processed data
processed_data = pd.read_csv('../../data/processed/processed_data.csv')
processed_data.head()
# Out:
#    Age    Salary Department
# 0   62  50403.04       Tech
# 1   18  65837.56  Marketing
# 2   21  48902.25       Tech
# 3   21  40014.19  Marketing
# 4   57  49338.31  Marketing

# %%
# Simple histogram of ages
plt.figure(figsize=(10, 6))
plt.hist(processed_data['Age'], bins=10, color='blue', alpha=0.7)
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()
